# %%
from numpy import *

# %%
import regression

# %%
xArr, yArr = regression.loadDataSet('ex0.txt')

# %%
xArr[:10]
# Out:
# [[1.0, 0.067732],
#  [1.0, 0.42781],
#  [1.0, 0.995731],
#  [1.0, 0.738336],
#  [1.0, 0.981083],
#  [1.0, 0.526171],
#  [1.0, 0.378887],
#  [1.0, 0.033859],
#  [1.0, 0.132791],
#  [1.0, 0.138306]]

# %%
mat(yArr).shape
# Out:
# (1L, 200L)

# %%
ws = regression.standRegres(xArr,yArr)

# %%
ws[0],ws[1]
# Out:
# (matrix([[3.00774324]]), matrix([[1.69532264]]))

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax = fig.add_subplot(111)

# %%
xMat, yMat = mat(xArr),mat(yArr)
yHat = xMat * ws

# %%
ax.scatter(xMat[:,1].flatten().A[0],yMat.T[:,0].flatten().A[0])

# %%
xCopy = xMat.copy()
xCopy.sort(0)
yHat = xCopy*ws
ax.plot(xCopy[:,1],yHat)
